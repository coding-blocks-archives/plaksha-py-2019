# %%
import cv2
import numpy as np

# %%
photo = cv2.imread("strange.jpg")

# %%
type(photo)
# Out:
# numpy.ndarray

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(photo)

# %%
blue = photo[:, :, 0]
green = photo[:, :, 1]
red = photo[:, :, 2]

# %%
plt.imshow(blue, cmap="gray")

# %%
red.shape
# Out:
# (464, 825)

# %%
blue.shape
# Out:
# (464, 825)

# %%
green.shape
# Out:
# (464, 825)

# %%
photo.dtype
# Out:
# dtype('uint8')

# %%
np.max(photo)
# Out:
# 255

# %%
# photo[:, :, 0] = red
# photo[:, :, 1] = green
# photo[:, :, 2] = blue

# %%
# plt.imshow(photo)

# %%
img = cv2.cvtColor(photo, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(img)

# %%
crop = img[0:300, 400:650]

# %%
plt.imshow(crop)

# %%
invert = 255 - crop

# %%
plt.imshow(invert)

# %%
arr = np.ones([10, 20, 3])

# %%
arr[0].shape
# Out:
# (20, 3)

# %%
arr[0][0].shape
# Out:
# (3,)

# %%
type(arr[0][0][0])
# Out:
# numpy.float64

# %%
ones = np.ones([2, 4])

# %%
data = np.arange(8).reshape(2, 4)

# %%
data
# Out:
# array([[0, 1, 2, 3],
#        [4, 5, 6, 7]])

# %%
ones
# Out:
# array([[1., 1., 1., 1.],
#        [1., 1., 1., 1.]])

# %%
data + ones
# Out:
# array([[1., 2., 3., 4.],
#        [5., 6., 7., 8.]])

# %%
small = np.arange(4)

# %%
small
# Out:
# array([0, 1, 2, 3])

# %%
ones + small
# Out:
# array([[1., 2., 3., 4.],
#        [1., 2., 3., 4.]])

# %%
ones + 4
# Out:
# array([[5., 5., 5., 5.],
#        [5., 5., 5., 5.]])

# %%
np.linspace(1, 5, 10)
# Out:
# array([1.        , 1.44444444, 1.88888889, 2.33333333, 2.77777778,
#        3.22222222, 3.66666667, 4.11111111, 4.55555556, 5.        ])

# %%
x = np.linspace(-20, 20, 100)

# %%
y = x**2

# %%
plt.plot(x, y)

# %%
cube = x**3

# %%
plt.plot(x, cube)

# %%
plt.figure()
plt.plot(x, y, label="square")
plt.plot(x, cube, label="cube")

plt.ylim(-500, 500)

plt.xlabel("input yaha jata hai")
plt.ylabel("output yha aata hai")
plt.title("Poore 20 number")
plt.legend()

plt.plot()
# Out:
# []

# %%
x = np.linspace(-np.pi, np.pi, 20)

# %%
sin = np.sin(x)
cos = np.cos(x)

# %%
plt.plot(x, sin)
plt.plot(x, cos)

# %%
plt.scatter(x, sin)
plt.scatter(x, cos)

# %%
from sklearn.datasets import make_blobs

# %%
points, klasses = make_blobs(n_samples=100, n_features=2, centers=2)

# %%
points.shape
# Out:
# (100, 2)

# %%
klasses.shape
# Out:
# (100,)

# %%
points, klasses = make_blobs(n_samples=100, n_features=2, centers=2, random_state=42)
plt.scatter(points[:, 0], points[:, 1], c=klasses)

# %%
x[:10]
# Out:
# array([[-6.64574978, -2.74796516],
#        [ 5.11041189, -1.18758249],
#        [ 5.54738807, -1.50116433],
#        [ 5.92218237, -0.95040455],
#        [-5.7315949 , -3.56162339],
#        [-6.5692804 , -3.72583787],
#        [ 4.68765357,  0.43043152],
#        [ 4.58329968, -0.61474843],
#        [ 4.96668988,  1.46113475],
#        [-6.74940625, -4.04838635]])

# %%
y[:10]
# Out:
# array([1, 0, 0, 0, 1, 1, 0, 0, 0, 1])

# %%
! push "l 8"
# Out:
# [master 4909f8c] l 8
#  4 files changed, 1035 insertions(+)
#  create mode 100644 session-9/.ipynb_checkpoints/numpy contn.-checkpoint.ipynb
#  create mode 100644 session-9/numpy contn..ipynb
#  create mode 100644 session-9/rb.jpg
#  create mode 100644 session-9/strange.jpg
# Enumerating objects: 8, done.
# Counting objects: 100% (8/8), done.
# Delta compression using up to 4 threads.
# Compressing objects: 100% (7/7), done.
# Writing objects: 100% (7/7), 621.40 KiB | 15.16 MiB/s, done.
# Total 7 (delta 1), reused 0 (delta 0)
# remote: Resolving deltas: 100% (1/1), completed with 1 local object.
# To https://github.com/coding-blocks-archives/plaksha-py-2019.git
#    e3bfdcc..4909f8c  master -> master
